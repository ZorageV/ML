# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv(r"C:\Zorage\Codes\ML\UNZIP_FOR_NOTEBOOKS_FINAL\03-Pandas\tips.csv")

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %%
df[df['sex']=="Male"]
# Out:
#      total_bill   tip   sex smoker  day    time  size  price_per_person  \
# 1         10.34  1.66  Male     No  Sun  Dinner     3              3.45
# 2         21.01  3.50  Male     No  Sun  Dinner     3              7.00
# 3         23.68  3.31  Male     No  Sun  Dinner     2             11.84
# 5         25.29  4.71  Male     No  Sun  Dinner     4              6.32
# 6          8.77  2.00  Male     No  Sun  Dinner     2              4.38
# ..          ...   ...   ...    ...  ...     ...   ...               ...
# 236       12.60  1.00  Male    Yes  Sat  Dinner     2              6.30
# 237       32.83  1.17  Male    Yes  Sat  Dinner     2             16.42
# 239       29.03  5.92  Male     No  Sat  Dinner     3              9.68
# 241       22.67  2.00  Male    Yes  Sat  Dinner     2             11.34
# 242       17.82  1.75  Male     No  Sat  Dinner     2              8.91
#
#              Payer Name         CC Number Payment ID
# ...

# %%
df[(df['total_bill']>30) & (df['sex']=='Male')] # AND operations use &
# Out:
#      total_bill    tip   sex smoker   day    time  size  price_per_person  \
# 23        39.42   7.58  Male     No   Sat  Dinner     4              9.86
# 39        31.27   5.00  Male     No   Sat  Dinner     3             10.42
# 44        30.40   5.60  Male     No   Sun  Dinner     4              7.60
# 47        32.40   6.00  Male     No   Sun  Dinner     4              8.10
# 56        38.01   3.00  Male    Yes   Sat  Dinner     4              9.50
# 59        48.27   6.73  Male     No   Sat  Dinner     4             12.07
# 83        32.68   5.00  Male    Yes  Thur   Lunch     2             16.34
# 95        40.17   4.73  Male    Yes   Fri  Dinner     4             10.04
# 112       38.07   4.00  Male     No   Sun  Dinner     3             12.69
# 141       34.30   6.70  Male     No  Thur   Lunch     6              5.72
# 142       41.19   5.00  Male     No  Thur   Lunch     5              8.24
# 156       48.17   5.00  Male     No   Sun  Dinner     6              8.03
# ...

# %%
df[(df['total_bill']>30) | (df['sex']=='Male')] #for OR operations use |
# Out:
#      total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 1         10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 5         25.29  4.71    Male     No  Sun  Dinner     4              6.32
# 6          8.77  2.00    Male     No  Sun  Dinner     2              4.38
# ..          ...   ...     ...    ...  ...     ...   ...               ...
# 237       32.83  1.17    Male    Yes  Sat  Dinner     2             16.42
# 238       35.83  4.67  Female     No  Sat  Dinner     3             11.94
# 239       29.03  5.92    Male     No  Sat  Dinner     3              9.68
# 241       22.67  2.00    Male    Yes  Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No  Sat  Dinner     2              8.91
#
#              Payer Name         CC Number Payment ID
# ...

# %%
df[(df['day']=='Sun') | (df['day']=='Sat') | (df['day']=='Fri')]
# Out:
#      total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No  Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...  ...     ...   ...               ...
# 238       35.83  4.67  Female     No  Sat  Dinner     3             11.94
# 239       29.03  5.92    Male     No  Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes  Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes  Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No  Sat  Dinner     2              8.91
#
#              Payer Name         CC Number Payment ID
# ...

# %%
#Use isin method to simplify the above code
options = ["Sun","Sat"]
df[df['day'].isin(options)]
# Out:
#      total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No  Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...  ...     ...   ...               ...
# 238       35.83  4.67  Female     No  Sat  Dinner     3             11.94
# 239       29.03  5.92    Male     No  Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes  Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes  Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No  Sat  Dinner     2              8.91
#
#              Payer Name         CC Number Payment ID
# ...

# %%
def last_four(num):
    return str(num)[-4:]

# %%
df['CC Number'].apply(last_four)
# Out:
# 0      3410
# 1      9230
# 2      1322
# 3      5994
# 4      7221
#        ...
# 239    2842
# 240    5404
# 241    7196
# 242    0950
# 243    8139
# Name: CC Number, Length: 244, dtype: object

# %%
df['last four'] = df['CC Number'].apply(last_four)

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID last four
# ...

# %%
def yelp(num):
    if num < 10:
        return '$'
    elif num < 30:
        return '$$'
    else:
        return '$$$'

# %%
df['yelp'] = df['total_bill'].apply(yelp)

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID last four yelp
# ...

# %%
df['total_bill'].apply(lambda num: num*2)
# Out:
# 0      33.98
# 1      20.68
# 2      42.02
# 3      47.36
# 4      49.18
#        ...
# 239    58.06
# 240    54.36
# 241    45.34
# 242    35.64
# 243    37.56
# Name: total_bill, Length: 244, dtype: float64

# %%
def quality(total_bill,tip):
    if(tip/total_bill > 0.25):
        return "Generous"
    return "Other"

# %%
quality(12,4)
# Out:
# 'Generous'

# %%
df[['total_bill','tip']].apply(lambda df : quality(df['total_bill'],df['tip']),axis=1)
# Out:
# 0      Other
# 1      Other
# 2      Other
# 3      Other
# 4      Other
#        ...
# 239    Other
# 240    Other
# 241    Other
# 242    Other
# 243    Other
# Length: 244, dtype: object

# %%
df['Quality'] = df[['total_bill','tip']].apply(lambda df : quality(df['total_bill'],df['tip']),axis=1)

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID last four yelp Quality
# 0  Christy Cunningham  3560325168603410    Sun2959      3410   $$   Other
# 1      Douglas Tucker  4478071379779230    Sun4608      9230   $$   Other
# 2      Travis Walters  6011812112971322    Sun4458      1322   $$   Other
# 3    Nathaniel Harris  4676137647685994    Sun5260      5994   $$   Other
# 4        Tonya Carter  4832732618637221    Sun2251      7221   $$   Other

# %%
df.drop('Quality',axis=1)
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID last four yelp
# ...

# %%
df['Quality'] = np.vectorize(quality)(df['total_bill'],df['tip']) #this is faster than previous code so use this method mostly
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
# ...

# %%
df.describe()
# Out:
#        total_bill         tip        size  price_per_person     CC Number
# count  244.000000  244.000000  244.000000        244.000000  2.440000e+02
# mean    19.785943    2.998279    2.569672          7.888197  2.563496e+15
# std      8.902412    1.383638    0.951100          2.914234  2.369340e+15
# min      3.070000    1.000000    1.000000          2.880000  6.040679e+10
# 25%     13.347500    2.000000    2.000000          5.800000  3.040731e+13
# 50%     17.795000    2.900000    2.000000          7.255000  3.525318e+15
# 75%     24.127500    3.562500    3.000000          9.390000  4.553675e+15
# max     50.810000   10.000000    6.000000         20.270000  6.596454e+15

# %%
df.sort_values(['tip'])
# Out:
#      total_bill    tip     sex smoker   day    time  size  price_per_person  \
# 67         3.07   1.00  Female    Yes   Sat  Dinner     1              3.07
# 236       12.60   1.00    Male    Yes   Sat  Dinner     2              6.30
# 92         5.75   1.00  Female    Yes   Fri  Dinner     2              2.88
# 111        7.25   1.00  Female     No   Sat  Dinner     1              7.25
# 0         16.99   1.01  Female     No   Sun  Dinner     2              8.49
# ..          ...    ...     ...    ...   ...     ...   ...               ...
# 141       34.30   6.70    Male     No  Thur   Lunch     6              5.72
# 59        48.27   6.73    Male     No   Sat  Dinner     4             12.07
# 23        39.42   7.58    Male     No   Sat  Dinner     4              9.86
# 212       48.33   9.00    Male     No   Sat  Dinner     4             12.08
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3             16.94
#
# ...

# %%
df.sort_values(['tip'],ascending=False)
# Out:
#      total_bill    tip     sex smoker   day    time  size  price_per_person  \
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3             16.94
# 212       48.33   9.00    Male     No   Sat  Dinner     4             12.08
# 23        39.42   7.58    Male     No   Sat  Dinner     4              9.86
# 59        48.27   6.73    Male     No   Sat  Dinner     4             12.07
# 141       34.30   6.70    Male     No  Thur   Lunch     6              5.72
# ..          ...    ...     ...    ...   ...     ...   ...               ...
# 0         16.99   1.01  Female     No   Sun  Dinner     2              8.49
# 236       12.60   1.00    Male    Yes   Sat  Dinner     2              6.30
# 111        7.25   1.00  Female     No   Sat  Dinner     1              7.25
# 67         3.07   1.00  Female    Yes   Sat  Dinner     1              3.07
# 92         5.75   1.00  Female    Yes   Fri  Dinner     2              2.88
#
# ...

# %%
df.sort_values(['tip','size'],ascending=True)
# Out:
#      total_bill    tip     sex smoker   day    time  size  price_per_person  \
# 67         3.07   1.00  Female    Yes   Sat  Dinner     1              3.07
# 111        7.25   1.00  Female     No   Sat  Dinner     1              7.25
# 92         5.75   1.00  Female    Yes   Fri  Dinner     2              2.88
# 236       12.60   1.00    Male    Yes   Sat  Dinner     2              6.30
# 0         16.99   1.01  Female     No   Sun  Dinner     2              8.49
# ..          ...    ...     ...    ...   ...     ...   ...               ...
# 141       34.30   6.70    Male     No  Thur   Lunch     6              5.72
# 59        48.27   6.73    Male     No   Sat  Dinner     4             12.07
# 23        39.42   7.58    Male     No   Sat  Dinner     4              9.86
# 212       48.33   9.00    Male     No   Sat  Dinner     4             12.08
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3             16.94
#
# ...

# %%
df['total_bill'].max()
# Out:
# 50.81

# %%
df['total_bill'].idxmax()
# Out:
# 170

# %%
df.iloc[170]
# Out:
# total_bill                     50.81
# tip                             10.0
# sex                             Male
# smoker                           Yes
# day                              Sat
# time                          Dinner
# size                               3
# price_per_person               16.94
# Payer Name             Gregory Clark
# CC Number           5473850968388236
# Payment ID                   Sat1954
# last four                       8236
# yelp                             $$$
# Quality                        Other
# Name: 170, dtype: object

# %%
df['tip'].min()
# Out:
# 1.0

# %%
df['total_bill'].idxmin()
# Out:
# 67

# %%
df.iloc[67]
# Out:
# total_bill                      3.07
# tip                              1.0
# sex                           Female
# smoker                           Yes
# day                              Sat
# time                          Dinner
# size                               1
# price_per_person                3.07
# Payer Name             Tiffany Brock
# CC Number           4359488526995267
# Payment ID                   Sat3455
# last four                       5267
# yelp                               $
# Quality                     Generous
# Name: 67, dtype: object

# %%
df.corr()
# Out:
# C:\Users\manje\AppData\Local\Temp\ipykernel_17536\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                   total_bill       tip      size  price_per_person  CC Number
# total_bill          1.000000  0.675734  0.598315          0.647554   0.104576
# tip                 0.675734  1.000000  0.489299          0.347405   0.110857
# size                0.598315  0.489299  1.000000         -0.175359  -0.030239
# price_per_person    0.647554  0.347405 -0.175359          1.000000   0.135240
# CC Number           0.104576  0.110857 -0.030239          0.135240   1.000000

# %%
df['sex'].value_counts()
# Out:
# Male      157
# Female     87
# Name: sex, dtype: int64

# %%
df['day'].unique()
# Out:
# array(['Sun', 'Sat', 'Thur', 'Fri'], dtype=object)

# %%
df['day'].value_counts()
# Out:
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: day, dtype: int64

# %%
df['sex'].replace('Female',"F")
# Out:
# 0         F
# 1      Male
# 2      Male
# 3      Male
# 4         F
#        ...
# 239    Male
# 240       F
# 241    Male
# 242    Male
# 243       F
# Name: sex, Length: 244, dtype: object

# %%
df['sex'].replace('Male',"M")
# Out:
# 0      Female
# 1           M
# 2           M
# 3           M
# 4      Female
#         ...
# 239         M
# 240    Female
# 241         M
# 242         M
# 243    Female
# Name: sex, Length: 244, dtype: object

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
# ...

# %%
df['sex'].replace(['Male','Female'],['M','F'])
# Out:
# 0      F
# 1      M
# 2      M
# 3      M
# 4      F
#       ..
# 239    M
# 240    F
# 241    M
# 242    M
# 243    F
# Name: sex, Length: 244, dtype: object

# %%
df['sex'].map({"Female": 'F', 'Male': "M"})
# Out:
# 0      F
# 1      M
# 2      M
# 3      M
# 4      F
#       ..
# 239    M
# 240    F
# 241    M
# 242    M
# 243    F
# Name: sex, Length: 244, dtype: object

# %%
simple_df = pd.DataFrame(data=[1,2,2],index=['a','b','c'])
simple_df
# Out:
#    0
# a  1
# b  2
# c  2

# %%
simple_df.duplicated()
# Out:
# a    False
# b    False
# c     True
# dtype: bool

# %%
simple_df = pd.DataFrame(data=[1,2,2,2],index=['a','b','c','d'])
simple_df
# Out:
#    0
# a  1
# b  2
# c  2
# d  2

# %%
simple_df.duplicated()
# Out:
# a    False
# b    False
# c     True
# d     True
# dtype: bool

# %%
df[df['total_bill'].between(10,20,inclusive=True)]
# Out:
# C:\Users\manje\AppData\Local\Temp\ipykernel_17536\1152120679.py:1: FutureWarning: Boolean inputs to the `inclusive` argument are deprecated in favour of `both` or `neither`.
#   df[df['total_bill'].between(10,20,inclusive=True)]
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 8         15.04  1.96    Male     No   Sun  Dinner     2              7.52
# 9         14.78  3.23    Male     No   Sun  Dinner     2              7.39
# 10        10.27  1.71    Male     No   Sun  Dinner     2              5.14
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 234       15.53  3.00    Male    Yes   Sat  Dinner     2              7.76
# 235       10.07  1.25    Male     No   Sat  Dinner     2              5.04
# ...

# %%
df.nlargest(2,['tip'])
# Out:
#      total_bill   tip   sex smoker  day    time  size  price_per_person  \
# 170       50.81  10.0  Male    Yes  Sat  Dinner     3             16.94
# 212       48.33   9.0  Male     No  Sat  Dinner     4             12.08
#
#           Payer Name         CC Number Payment ID last four yelp Quality
# 170    Gregory Clark  5473850968388236    Sat1954      8236  $$$   Other
# 212  Alex Williamson      676218815212    Sat4590      5212  $$$   Other

# %%
df.nsmallest(2,['tip'])
# Out:
#     total_bill  tip     sex smoker  day    time  size  price_per_person  \
# 67        3.07  1.0  Female    Yes  Sat  Dinner     1              3.07
# 92        5.75  1.0  Female    Yes  Fri  Dinner     2              2.88
#
#        Payer Name         CC Number Payment ID last four yelp   Quality
# 67  Tiffany Brock  4359488526995267    Sat3455      5267    $  Generous
# 92   Leah Ramirez  3508911676966392    Fri3780      6392    $     Other

# %%
df.sample(5)
# Out:
#      total_bill  tip     sex smoker   day    time  size  price_per_person  \
# 101       15.38  3.0  Female    Yes   Fri  Dinner     2              7.69
# 167       31.71  4.5    Male     No   Sun  Dinner     4              7.93
# 51        10.29  2.6  Female     No   Sun  Dinner     2              5.14
# 28        21.70  4.3    Male     No   Sat  Dinner     2             10.85
# 80        19.44  3.0    Male    Yes  Thur   Lunch     2              9.72
#
#          Payer Name         CC Number Payment ID last four yelp   Quality
# 101   Tiffany Colon  6011012799432041    Fri8382      2041   $$     Other
# 167  Michael Lawson  3566285921227119    Sun3719      7119  $$$     Other
# 51   Jessica Ibarra     4999759463713    Sun4474      3713   $$  Generous
# 28    David Collier  5529694315416009    Sat3697      6009   $$     Other
# 80     Louis Torres    38848369968464   Thur6453      8464   $$     Other

# %%
df.sample(frac=0.1) #10% of sample is returned
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 58        11.24  1.76    Male    Yes   Sat  Dinner     2              5.62
# 217       11.59  1.50    Male    Yes   Sat  Dinner     2              5.80
# 34        17.78  3.27    Male     No   Sat  Dinner     2              8.89
# 57        26.41  1.50  Female     No   Sat  Dinner     2             13.20
# 122       14.26  2.50    Male     No  Thur   Lunch     2              7.13
# 175       32.90  3.11    Male    Yes   Sun  Dinner     2             16.45
# 77        27.20  4.00    Male     No  Thur   Lunch     4              6.80
# 93        16.32  4.30  Female    Yes   Fri  Dinner     2              8.16
# 204       20.53  4.00    Male    Yes  Thur   Lunch     4              5.13
# 153       24.55  2.00    Male     No   Sun  Dinner     4              6.14
# 187       30.46  2.00    Male    Yes   Sun  Dinner     5              6.09
# ...
